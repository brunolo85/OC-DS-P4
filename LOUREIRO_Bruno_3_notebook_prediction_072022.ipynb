# %% [markdown]
# # Projet 4 : Anticipez les besoins en consommation de bâtiments
#
# Notebook de prédiction de la consommation totale d'énergie
#
# # Sommaire
#  - <a href="#C1">Importation des éléments nécessaires</a>
#  - <a href="#C2">Fonctions</a>
#  - <a href="#C3">Paramètres</a>
#  - <a href="#C4">Evaluation des modèles de prédiction</a>
#      - <a href="#C4.1">Données sans Energy Star Score</a>
#      - <a href="#C4.2">Données avec Energy Star Score</a>
#          - <a href="#C4.2.1">Données réelles</a>
#          - <a href="#C4.2.2">Données réelles + données prédites</a>

# %% [markdown]
# # <a name="C1"> Importation des éléments nécessaires

# %%
# Importation des librairies nécessaires
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as st

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn import metrics

from sklearn import linear_model, kernel_ridge, svm, neighbors
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neural_network import MLPRegressor

import plotly.graph_objects as go
import plotly.offline as pyo

# Librairies pour ACP
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.cluster import KMeans
from sklearn import decomposition
from matplotlib.collections import LineCollection

import datetime

# %%
# Importation des données dans un DataFrame
data_final = pd.read_csv('data_final.csv', index_col=0)

# %%
# Paramétrer l'affichage des résultats
pd.set_option('display.max_rows',70)
pd.set_option('display.max_columns',70)
pd.options.display.float_format = "{:,.4f}".format

# %% [markdown]
# # <a name="C2"> Fonctions

# %%
# Fonctions pour passer en NaN les valeurs aberrantes (ici inférieures à 0)
def mistakes(df,var):
    mask_0 = df[var] < 0
    df.loc[mask_0, var] = np.NaN

# %%
# Fonction de traitement des outliers en fonction des quartiles
def outliers(df,var):
    # calculer les quartiles
    Q1 = df[var].quantile(0.25)
    Q3 = df[var].quantile(0.75)
    IQ = Q3-Q1
    mini = Q1-1.5*IQ
    maxi = Q3+1.5*IQ
    # mettre les outliers à NaN
    mask_mini = df[var] < mini
    df.loc[mask_mini, var] = np.NaN
    mask_maxi = df[var] > maxi
    df.loc[mask_maxi, var] = np.NaN

# %%
# Fonctions pour l'ACP
def display_circles(pcs, n_comp, pca, axis_ranks, labels=None, label_rotation=0, lims=None):
    for d1, d2 in axis_ranks: # On affiche les 3 premiers plans factoriels, donc les 6 premières composantes
        if d2 < n_comp:

            # initialisation de la figure
            fig, ax = plt.subplots(figsize=(7,6))

            # détermination des limites du graphique
            if lims is not None :
                xmin, xmax, ymin, ymax = lims
            elif pcs.shape[1] < 30 :
                xmin, xmax, ymin, ymax = -1, 1, -1, 1
            else :
                xmin, xmax, ymin, ymax = min(pcs[d1,:]), max(pcs[d1,:]), min(pcs[d2,:]), max(pcs[d2,:])

            # affichage des flèches
            # s'il y a plus de 30 flèches, on n'affiche pas le triangle à leur extrémité
            if pcs.shape[1] < 30 :
                plt.quiver(np.zeros(pcs.shape[1]), np.zeros(pcs.shape[1]),
                   pcs[d1,:], pcs[d2,:], 
                   angles='xy', scale_units='xy', scale=1, color="grey")
                # (voir la doc : https://matplotlib.org/api/_as_gen/matplotlib.pyplot.quiver.html)
            else:
                lines = [[[0,0],[x,y]] for x,y in pcs[[d1,d2]].T]
                ax.add_collection(LineCollection(lines, axes=ax, alpha=.1, color='black'))
            
            # affichage des noms des variables  
            if labels is not None:  
                for i,(x, y) in enumerate(pcs[[d1,d2]].T):
                    if x >= xmin and x <= xmax and y >= ymin and y <= ymax :
                        plt.text(x, y, labels[i], fontsize='14', ha='center', va='center', rotation=label_rotation, color="blue", alpha=0.5)
            
            # affichage du cercle
            circle = plt.Circle((0,0), 1, facecolor='none', edgecolor='b')
            plt.gca().add_artist(circle)

            # définition des limites du graphique
            plt.xlim(xmin, xmax)
            plt.ylim(ymin, ymax)
        
            # affichage des lignes horizontales et verticales
            plt.plot([-1, 1], [0, 0], color='grey', ls='--')
            plt.plot([0, 0], [-1, 1], color='grey', ls='--')

            # nom des axes, avec le pourcentage d'inertie expliqué
            plt.xlabel('F{} ({}%)'.format(d1+1, round(100*pca.explained_variance_ratio_[d1],1)))
            plt.ylabel('F{} ({}%)'.format(d2+1, round(100*pca.explained_variance_ratio_[d2],1)))

            plt.title("Cercle des corrélations (F{} et F{})".format(d1+1, d2+1))
            plt.show(block=False)
        
def display_factorial_planes(X_projected, n_comp, pca, axis_ranks, labels=None, alpha=1, illustrative_var=None):
    for d1,d2 in axis_ranks:
        if d2 < n_comp:
 
            # initialisation de la figure       
            fig = plt.figure(figsize=(7,6))
        
            # affichage des points
            if illustrative_var is None:
                plt.scatter(X_projected[:, d1], X_projected[:, d2], alpha=alpha)
            else:
                illustrative_var = np.array(illustrative_var)
                for value in np.unique(illustrative_var):
                    selected = np.where(illustrative_var == value)
                    plt.scatter(X_projected[selected, d1], X_projected[selected, d2], alpha=alpha, label=value)
                plt.legend()

            # affichage des labels des points
            if labels is not None:
                for i,(x,y) in enumerate(X_projected[:,[d1,d2]]):
                    plt.text(x, y, labels[i],
                              fontsize='14', ha='center',va='center') 
                
            # détermination des limites du graphique
            boundary = np.max(np.abs(X_projected[:, [d1,d2]])) * 1.1
            plt.xlim([-boundary,boundary])
            plt.ylim([-boundary,boundary])
        
            # affichage des lignes horizontales et verticales
            plt.plot([-100, 100], [0, 0], color='grey', ls='--')
            plt.plot([0, 0], [-100, 100], color='grey', ls='--')

            # nom des axes, avec le pourcentage d'inertie expliqué
            plt.xlabel('F{} ({}%)'.format(d1+1, round(100*pca.explained_variance_ratio_[d1],1)))
            plt.ylabel('F{} ({}%)'.format(d2+1, round(100*pca.explained_variance_ratio_[d2],1)))

            plt.title("Projection des individus (sur F{} et F{})".format(d1+1, d2+1))
            plt.show(block=False)

def display_scree_plot(pca):
    scree = pca.explained_variance_ratio_*100
    plt.bar(np.arange(len(scree))+1, scree)
    plt.plot(np.arange(len(scree))+1, scree.cumsum(),c="red",marker='o')
    plt.xlabel("rang de l'axe d'inertie")
    plt.ylabel("pourcentage d'inertie")
    plt.title("Eboulis des valeurs propres")
    plt.show(block=False)

# %% [markdown]
# # <a name="C3"> Paramètres

# %%
# Aperçu des données
data_final.describe()
# Out:
#        CouncilDistrictCode   Latitude  Longitude  YearBuilt  NumberofFloors  \
# count           1,153.0000 1,153.0000 1,153.0000 1,153.0000      1,153.0000
# mean                4.0442    47.6151  -122.3329 1,959.0416          2.4761
# std                 2.1418     0.0516     0.0256    32.0522          1.5331
# min                 1.0000    47.4992  -122.4118 1,900.0000          0.0000
# 25%                 2.0000    47.5753  -122.3446 1,929.0000          1.0000
# 50%                 4.0000    47.6128  -122.3320 1,962.0000          2.0000
# 75%                 6.0000    47.6557  -122.3206 1,984.0000          3.0000
# max                 7.0000    47.7339  -122.2586 2,015.0000          8.0000
#
#        ENERGYSTARScore  Enc_ComplianceStatus   mix_elec    mix_gas  mix_steam  \
# count       1,153.0000            1,153.0000 1,153.0000 1,153.0000 1,153.0000
# mean           43.8699                0.0642     0.7123     0.2877     0.0000
# std            38.4282                0.2452     0.2651     0.2651     0.0000
# min             0.0000                0.0000     0.0045     0.0000     0.0000
# 25%             0.0000                0.0000     0.4987     0.0000     0.0000
# 50%            50.0000                0.0000     0.7359     0.2641     0.0000
# 75%            82.0000                0.0000     1.0000     0.5013     0.0000
# max           100.0000                1.0000     1.0000     0.9955     0.0000
#
#
#        Type_Bar/Nightclub  Type_Data Center  Type_Enclosed Mall  \
# count          1,153.0000        1,153.0000          1,153.0000
# mean               0.0003            0.0002              0.0003
# std                0.0071            0.0044              0.0100
# min                0.0000            0.0000              0.0000
# 25%                0.0000            0.0000              0.0000
# 50%                0.0000            0.0000              0.0000
# 75%                0.0000            0.0000              0.0000
# max                0.2334            0.1228              0.3390
#
#        Type_Food Sales  Type_Unknown  Type_Vocational School  \
# count       1,153.0000    1,153.0000              1,153.0000
# mean            0.0003        0.0373                  0.0005
# std             0.0088        0.0976                  0.0126
# min             0.0000        0.0000                  0.0000
# 25%             0.0000        0.0000                  0.0000
# 50%             0.0000        0.0000                  0.0000
# 75%             0.0000        0.0085                  0.0000
# max             0.3000        0.7820                  0.3995
#
#        Type_Fast Food Restaurant  Neighbor_BALLARD  Neighbor_CENTRAL  \
# count                 1,153.0000        1,153.0000        1,153.0000
# mean                      0.0000            0.0468            0.0338
# std                       0.0015            0.2114            0.1809
# min                       0.0000            0.0000            0.0000
# 25%                       0.0000            0.0000            0.0000
# 50%                       0.0000            0.0000            0.0000
# 75%                       0.0000            0.0000            0.0000
# max                       0.0510            1.0000            1.0000
#
#        Neighbor_DELRIDGE  Neighbor_DOWNTOWN  Neighbor_EAST  \
# count         1,153.0000         1,153.0000     1,153.0000
# mean              0.0330             0.1492         0.0607
# std               0.1786             0.3564         0.2389
# min               0.0000             0.0000         0.0000
# 25%               0.0000             0.0000         0.0000
# 50%               0.0000             0.0000         0.0000
# 75%               0.0000             0.0000         0.0000
# max               1.0000             1.0000         1.0000
#
#        Neighbor_GREATER DUWAMISH  Neighbor_LAKE UNION  \
# count                 1,153.0000           1,153.0000
# mean                      0.2611               0.0824
# std                       0.4394               0.2751
# min                       0.0000               0.0000
# 25%                       0.0000               0.0000
# 50%                       0.0000               0.0000
# 75%                       1.0000               0.0000
# max                       1.0000               1.0000
#
#        Neighbor_MAGNOLIA / QUEEN ANNE  Neighbor_NORTH  Neighbor_NORTHEAST  \
# count                      1,153.0000      1,153.0000          1,153.0000
# mean                           0.0937          0.0434              0.0815
# std                            0.2915          0.2038              0.2738
# min                            0.0000          0.0000              0.0000
# 25%                            0.0000          0.0000              0.0000
# 50%                            0.0000          0.0000              0.0000
# 75%                            0.0000          0.0000              0.0000
# max                            1.0000          1.0000              1.0000
#
#        Neighbor_NORTHWEST  Neighbor_SOUTHEAST  Neighbor_SOUTHWEST
# count          1,153.0000          1,153.0000          1,153.0000
# mean               0.0598              0.0304              0.0243
# std                0.2373              0.1716              0.1540
# min                0.0000              0.0000              0.0000
# 25%                0.0000              0.0000              0.0000
# 50%                0.0000              0.0000              0.0000
# 75%                0.0000              0.0000              0.0000
# max                1.0000              1.0000              1.0000
#
# [8 rows x 111 columns]

# %%
data_final.head(5)
# Out:
#     CouncilDistrictCode  Latitude  Longitude  YearBuilt  NumberofFloors  \
# 22                    2   47.5458  -122.2685 1,961.0000          2.0000
# 23                    4   47.6596  -122.3175 2,001.0000          6.0000
# 25                    7   47.6150  -122.3308 1,930.0000          2.0000
# 29                    7   47.6156  -122.3419 1,978.0000          5.0000
# 32                    4   47.6641  -122.3312 1,906.0000          3.0000
#
#     ENERGYSTARScore  Enc_ComplianceStatus  mix_elec  mix_gas  mix_steam  \
# 22          95.0000                     1    0.6086   0.3914     0.0000
# 23          84.0000                     0    0.6186   0.3814     0.0000
# 25           0.0000                     0    1.0000   0.0000     0.0000
# 29          57.0000                     0    0.5265   0.4735     0.0000
# 32           0.0000                     0    0.3263   0.6737     0.0000
#
#     New_PropertyGFATotal  New_SiteEUIWN(kBtu/sf)  New_GHGEmissionsIntensity  \
# 22           58,916.0000                 29.0859                     0.6500
# 23           88,592.0000                 41.4618                     1.0200
# 25           67,224.0000                 19.4906                     0.1400
# 29           68,410.0000                 66.6273                     1.8800
# 32           87,262.0000                 53.9031                     1.8100
#
#     Building_Campus  Building_NonResidential  Building_Nonresidential COS  \
# 22                0                        0                            0
# 23                0                        1                            0
# 25                0                        1                            0
# 29                0                        1                            0
# 32                0                        1                            0
#
#     Building_Nonresidential WA  Building_SPS-District K-12  \
# 22                           0                           1
# 23                           0                           0
# 25                           0                           0
# 29                           0                           0
# 32                           0                           0
#
#     Primary_Distribution Center  Primary_Hospital  Primary_Hotel  \
# 22                            0                 0              0
# 23                            0                 0              1
# 25                            0                 0              0
# 29                            0                 0              1
# 32                            0                 0              0
#
#     Primary_K-12 School  Primary_Laboratory  Primary_Large Office  \
# 22                    1                   0                     0
# 23                    0                   0                     0
# 25                    0                   0                     0
# 29                    0                   0                     0
# 32                    0                   0                     0
#
#     Primary_Low-Rise Multifamily  Primary_Medical Office  \
# 22                             0                       0
# 23                             0                       0
# 25                             0                       0
# 29                             0                       0
# 32                             0                       0
#
#     Primary_Mixed Use Property  Primary_Office  Primary_Other  \
# 22                           0               0              0
# 23                           0               0              0
# 25                           0               0              1
# 29                           0               0              0
# 32                           0               0              0
#
#     Primary_Refrigerated Warehouse  Primary_Residence Hall  \
# 22                               0                       0
# 23                               0                       0
# 25                               0                       0
# 29                               0                       0
# 32                               0                       0
#
#     Primary_Restaurant  Primary_Retail Store  Primary_Self-Storage Facility  \
# 22                   0                     0                              0
# 23                   0                     0                              0
# 25                   0                     0                              0
# 29                   0                     0                              0
# 32                   0                     0                              0
#
#     Primary_Senior Care Community  ...  Type_Prison/Incarceration  \
# 22                              0  ...                     0.0000
# 23                              0  ...                     0.0000
# 25                              0  ...                     0.0000
# 29                              0  ...                     0.0000
# 32                              0  ...                     0.0000
#
#     Type_Refrigerated Warehouse  \
# 22                       0.0000
# 23                       0.0000
# 25                       0.0000
# 29                       0.0000
# 32                       0.0000
#
#     Type_Repair Services (Vehicle, Shoe, Locksmith, etc)  \
# 22                                             0.0000
# 23                                             0.0000
# 25                                             0.0000
# 29                                             0.0000
# 32                                             0.0000
#
#     Type_Residence Hall/Dormitory  Type_Residential Care Facility  \
# 22                         0.0000                          0.0000
# 23                         0.0000                          0.0000
# 25                         0.0000                          0.0000
# 29                         0.0000                          0.0000
# 32                         0.0000                          0.0000
#
#     Type_Restaurant  Type_Retail Store  Type_Self-Storage Facility  \
# 22           0.0000             0.0000                      0.0000
# 23           0.0000             0.0000                      0.0000
# 25           0.0000             0.0000                      0.0000
# 29           0.0000             0.0000                      0.0000
# 32           0.0000             0.0000                      0.0000
#
#     Type_Senior Care Community  Type_Social/Meeting Hall  Type_Strip Mall  \
# 22                      0.0000                    0.0000           0.0000
# 23                      0.0000                    0.0000           0.0000
# 25                      0.0000                    0.0000           0.0000
# 29                      0.0000                    0.0000           0.0000
# 32                      0.0000                    0.0000           0.0000
#
#     Type_Supermarket/Grocery Store  Type_Urgent Care/Clinic/Other Outpatient  \
# 22                          0.0000                                    0.0000
# 23                          0.0000                                    0.0000
# 25                          0.0000                                    0.0000
# 29                          0.0000                                    0.0000
# 32                          0.0000                                    0.0000
#
#     Type_Wholesale Club/Supercenter  Type_Worship Facility  \
# 22                           0.0000                 0.0000
# 23                           0.0000                 0.0000
# 25                           0.0000                 0.0000
# 29                           0.0000                 0.0000
# 32                           0.0000                 0.0000
#
#     Type_Bar/Nightclub  Type_Data Center  Type_Enclosed Mall  Type_Food Sales  \
# 22              0.0000            0.0000              0.0000           0.0000
# 23              0.0000            0.0000              0.0000           0.0000
# 25              0.0000            0.0000              0.0000           0.0000
# 29              0.0000            0.0000              0.0000           0.0000
# 32              0.0000            0.0000              0.0000           0.0000
#
#     Type_Unknown  Type_Vocational School  Type_Fast Food Restaurant  \
# 22        0.0000                  0.0000                     0.0000
# 23        0.0000                  0.0000                     0.0000
# 25        0.0000                  0.0000                     0.0000
# 29        0.2984                  0.0000                     0.0000
# 32        0.2734                  0.0000                     0.0000
#
#     Neighbor_BALLARD  Neighbor_CENTRAL  Neighbor_DELRIDGE  Neighbor_DOWNTOWN  \
# 22                 0                 0                  0                  0
# 23                 0                 0                  0                  0
# 25                 0                 0                  0                  1
# 29                 0                 0                  0                  1
# 32                 0                 0                  0                  0
#
#     Neighbor_EAST  Neighbor_GREATER DUWAMISH  Neighbor_LAKE UNION  \
# 22              0                          0                    0
# 23              0                          0                    0
# 25              0                          0                    0
# 29              0                          0                    0
# 32              0                          0                    1
#
#     Neighbor_MAGNOLIA / QUEEN ANNE  Neighbor_NORTH  Neighbor_NORTHEAST  \
# 22                               0               0                   0
# 23                               0               0                   1
# 25                               0               0                   0
# 29                               0               0                   0
# 32                               0               0                   0
#
#     Neighbor_NORTHWEST  Neighbor_SOUTHEAST  Neighbor_SOUTHWEST
# 22                   0                   1                   0
# 23                   0                   0                   0
# 25                   0                   0                   0
# 29                   0                   0                   0
# 32                   0                   0                   0
#
# [5 rows x 111 columns]

# %%
# colonnes à centrer / réduire  - 'ENERGYSTARScore' exclu
col_std = ['CouncilDistrictCode', 'Latitude', 'Longitude', 'YearBuilt', 
           'NumberofFloors', 'New_PropertyGFATotal']

# colonnes à centrer / réduire  - 'ENERGYSTARScore' inclu
col_std_2 = ['CouncilDistrictCode', 'Latitude', 'Longitude', 'YearBuilt', 
           'NumberofFloors', 'ENERGYSTARScore', 'New_PropertyGFATotal']

# colonnes à centrer / réduire pour la prédiction de l'Energy Star
col_std_3 = ['CouncilDistrictCode', 'Latitude', 'Longitude', 'YearBuilt', 'NumberofFloors', 
             'New_PropertyGFATotal', 'New_SiteEUIWN(kBtu/sf)', 'New_GHGEmissionsIntensity']

# features X pour la prédiction - 'ENERGYSTARScore' exclu
features_analysis = data_final.columns[~data_final.columns.isin(['New_SiteEUIWN(kBtu/sf)',
                                                                 'New_GHGEmissionsIntensity', 'ENERGYSTARScore'])]

# features X pour la prédiction - 'ENERGYSTARScore' inclu
features_analysis_2 = data_final.columns[~data_final.columns.isin(['New_SiteEUIWN(kBtu/sf)', 'New_GHGEmissionsIntensity'])]

print("Nombre de variables X ('ENERGYSTARScore' exclu) :", len(features_analysis))
print("Nombre de variables X ('ENERGYSTARScore' inclu) :", len(features_analysis_2))
# Out:
# Nombre de variables X ('ENERGYSTARScore' exclu) : 108
# Nombre de variables X ('ENERGYSTARScore' inclu) : 109

# %%
# Initialisation des modèles et de leurs paramètres

# Paramètres
random = 42
splits = 10
score = 'r2'
tolerance = [0.01]

n_alphas = 10
alphas = np.logspace(-5, 5, n_alphas)
Cs = np.logspace(-5, 5, n_alphas)
gammas = np.logspace(-5, 5, n_alphas)

layers = range(60, 70, 5)
iteration = [5000]
estimators = range(450, 650, 100)
l1 = np.arange(0.7, 1, 0.1)
learning_rate = np.arange(0.02, 0.09, 0.03)
kernel = ['rbf']
iter_calc = [20000]

# Modèles à utiliser
ridge = linear_model.Ridge(random_state = random)
lasso = linear_model.Lasso(random_state = random)
net = linear_model.ElasticNet(random_state = random)
krr = kernel_ridge.KernelRidge()
svr = svm.SVR(cache_size = 4000)
rfr = RandomForestRegressor(oob_score=True, random_state = random)
gbr = GradientBoostingRegressor(random_state = random)
mlp = MLPRegressor(random_state = random)

# %% [markdown]
# # <a name="C4"> Evaluation des modèles de prédiction

# %% [markdown]
# ## <a name="C4.1"> Données sans Energy Star Score

# %%
# Tests des modèles de prédiction de la consommation d'énergie

# Les données
y = data_final['New_SiteEUIWN(kBtu/sf)']
X = data_final[features_analysis]

# Ne standardisons que les variables qui en ont besoin
X_std = X.copy()
for col in col_std:
    mean = X[col].mean()
    std = X[col].std()
    X_std[col] = (X[col]-mean) / std
X_std.shape
# Out:
# (1153, 108)

# %%
# Algo d'entrainement des modèles
# Titre
print("Modèles de prédiction des émissions de la consommation d'énergie (sans prendre en compte l'Energy Star Score):")
print(70*'-')

# Début des traitements
start = datetime.datetime.now()

# Données
X_train = X_std
y_train = y

# Ridge
params = { 'alpha': alphas, 'tol' : tolerance }
gs_ridge = GridSearchCV(ridge, params, scoring = score, cv=splits)
gs_ridge.fit(X_train, y_train)
print('Ridge :', gs_ridge.best_params_)
init_sum = [('Ridge', round(gs_ridge.best_score_*100,2))]
summary = pd.DataFrame(init_sum, columns = ['Model', 'R2'])

# Lasso
params = { 'alpha': alphas, 'tol' : tolerance , 'max_iter' : iter_calc }
gs_lasso = GridSearchCV(lasso, params, scoring = score, cv=splits)
gs_lasso.fit(X_train, y_train)
print('Lasso :', gs_lasso.best_params_)
summary.loc[1] = ['Lasso', round(gs_lasso.best_score_*100,2)]

# Elastic Net
params = { 'alpha': alphas, 'l1_ratio' : l1, 'tol' : tolerance,  'max_iter' : iter_calc }
gs_net = GridSearchCV(net, params, scoring = score, cv=splits)
gs_net.fit(X_train, y_train)
print('Elastic Net :', gs_net.best_params_)
summary.loc[2] = ['Elastic Net', round(gs_net.best_score_*100,2)]

# Kernel Ridge Regression
params = { 'alpha': alphas, 'gamma' : gammas, 'kernel' : kernel }
gs_krr = GridSearchCV(krr, params, scoring = score, cv=splits)
gs_krr.fit(X_train, y_train)
print('Kernel Ridge Regression :', gs_krr.best_params_)
summary.loc[3] = ['Kernel Ridge Regression', round(gs_krr.best_score_*100,2)]


# Random Forest Regressor
params = {'n_estimators': estimators}
gs_rfr = GridSearchCV(rfr, params, scoring = score, cv=splits)
gs_rfr.fit(X_train, y_train)
print('Random Forest Regressor :', gs_rfr.best_params_)
summary.loc[4] = ['Random Forest Regressor', round(gs_rfr.best_score_*100,2)]

# Gradient Boosting Regressor
params = {'n_estimators': estimators, 'learning_rate': learning_rate}
gs_gbr = GridSearchCV(gbr, params, scoring = score, cv=splits)
gs_gbr.fit(X_train, y_train)
print('Gradient Boosting Regressor :', gs_gbr.best_params_)
summary.loc[5] = ['Gradient Boosting Regressor', round(gs_gbr.best_score_*100,2)]

# Multi-Layer Perceptron Regressor
params = {'hidden_layer_sizes': layers, 'max_iter': iteration, 'alpha': alphas}
gs_mlp = GridSearchCV(mlp, params, scoring = score, cv=splits)
gs_mlp.fit(X_train, y_train)
print('Multi-Layer Perceptron Regressor :', gs_mlp.best_params_)
summary.loc[6] = ['Multi-Layer Perceptron Regressor', round(gs_mlp.best_score_*100,2)]

# Support Vector Regression
params = { 'C': Cs, 'tol' : tolerance, 'kernel' : kernel }
gs_svr = GridSearchCV(svr, params, scoring = score, cv=splits)
gs_svr.fit(X_train, y_train)
print('Support Vector Regression :', gs_svr.best_params_)
summary.loc[7] = ['Support Vector Regression', round(gs_svr.best_score_*100,2)]

# Fin des traitements
end = datetime.datetime.now()
print(70*'-')
print ("Start date and time : ", start.strftime("%Y-%m-%d %H:%M:%S"))
print ("End date and time : ", end.strftime("%Y-%m-%d %H:%M:%S"))

# Trions et affichons les résultats
summary = summary.sort_values(by = 'R2',ascending = False)
summary
# Out:
# Modèles de prédiction des émissions de la consommation d'énergie (sans prendre en compte l'Energy Star Score):
# ----------------------------------------------------------------------
# Ridge : {'alpha': 3.593813663804626, 'tol': 0.01}
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 55804.85974748491, tolerance: 7783.108897253274
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 58603.74355987366, tolerance: 7864.882050515132
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 57472.90512953792, tolerance: 7812.607293311015
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 47311.555834469735, tolerance: 7646.246179842135
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 38905.47952548438, tolerance: 7573.046094956035
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 58324.03504309352, tolerance: 7712.53196386153
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 54601.7329031846, tolerance: 7614.324080667566
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 73998.89925990609, tolerance: 7260.238849475109
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 56861.22176708619, tolerance: 7818.901561952541
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 103347.56294458112, tolerance: 7385.643195332291
# Lasso : {'alpha': 0.021544346900318846, 'max_iter': 20000, 'tol': 0.01}
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 18518.32709697797, tolerance: 7783.108897253274
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 29752.99768380483, tolerance: 7864.882050515132
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23213.281461887644, tolerance: 7812.607293311015
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24832.954408288875, tolerance: 7646.246179842135
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 52404.668391346, tolerance: 7712.53196386153
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 30971.625807710167, tolerance: 7614.324080667566
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23276.124634149775, tolerance: 7260.238849475109
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 15818.534410030232, tolerance: 7818.901561952541
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 60823.42032742317, tolerance: 7385.643195332291
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23054.466689125402, tolerance: 7783.108897253274
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 52470.73406460445, tolerance: 7864.882050515132
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 44530.26689163485, tolerance: 7812.607293311015
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 42274.39269035187, tolerance: 7646.246179842135
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 83165.6610822512, tolerance: 7712.53196386153
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 55629.88151937787, tolerance: 7614.324080667566
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 43905.05897802184, tolerance: 7260.238849475109
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 34620.30265390029, tolerance: 7818.901561952541
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 85674.64750030154, tolerance: 7385.643195332291
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 72531.75226732637, tolerance: 7864.882050515132
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 65712.31431597596, tolerance: 7812.607293311015
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 51129.16998718947, tolerance: 7646.246179842135
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 103409.84178397924, tolerance: 7712.53196386153
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 76384.16470536473, tolerance: 7614.324080667566
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 63575.92176812689, tolerance: 7260.238849475109
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 57005.43821717007, tolerance: 7818.901561952541
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 92236.3958961617, tolerance: 7385.643195332291
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 55804.859748828865, tolerance: 7783.108897253274
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 58603.74356209161, tolerance: 7864.882050515132
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 57472.90512912802, tolerance: 7812.607293311015
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 47311.55584236665, tolerance: 7646.246179842135
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 38905.47952216159, tolerance: 7573.046094956035
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 58324.03504398334, tolerance: 7712.53196386153
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 54601.73290465222, tolerance: 7614.324080667566
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 73998.89926056107, tolerance: 7260.238849475109
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 56861.221768390446, tolerance: 7818.901561952541
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 103347.56294458339, tolerance: 7385.643195332291
# Elastic Net : {'alpha': 0.021544346900318846, 'l1_ratio': 0.7, 'max_iter': 20000, 'tol': 0.01}
# Kernel Ridge Regression : {'alpha': 0.2782559402207126, 'gamma': 0.021544346900318846, 'kernel': 'rbf'}
# Random Forest Regressor : {'n_estimators': 450}
# Gradient Boosting Regressor : {'learning_rate': 0.02, 'n_estimators': 450}
# Multi-Layer Perceptron Regressor : {'alpha': 46.41588833612782, 'hidden_layer_sizes': 60, 'max_iter': 5000}
# Support Vector Regression : {'C': 46.41588833612782, 'kernel': 'rbf', 'tol': 0.01}
# ----------------------------------------------------------------------
# Start date and time :  2022-08-31 23:05:09
# End date and time :  2022-09-01 00:03:47
#                               Model      R2
# 5       Gradient Boosting Regressor 20.9100
# 6  Multi-Layer Perceptron Regressor 20.4100
# 3           Kernel Ridge Regression 19.8300
# 4           Random Forest Regressor 19.6400
# 2                       Elastic Net 18.9600
# 0                             Ridge 18.1800
# 1                             Lasso 17.3800
# 7         Support Vector Regression 14.0100

# %%
# Tentons d'optimiser les hyperparamètres des meilleurs modèles qui ressortent de nos premiers tests

# Gradient Boosting Regressor
# Meilleur paramètre en première analyse : 
# {'learning_rate': 0.02, 'n_estimators': 450}

# nouveaux paramètres
params = {'n_estimators': [432], 'learning_rate': [0.0211]}

gs_gbr = GridSearchCV(gbr, params, scoring = score, cv=splits)
gs_gbr.fit(X_train, y_train)
print('Gradient Boosting Regressor')
print('Params :', gs_gbr.best_params_)
print('Score', round(gs_gbr.best_score_*100,2))
# Out:
# Gradient Boosting Regressor
# Params : {'learning_rate': 0.0211, 'n_estimators': 432}
# Score 21.11

# %%
# Multi-Layer Perceptron Regressor
# Meilleur paramètre en première analyse : 
# {'alpha': 46.41588833612782, 'hidden_layer_sizes': 60, 'max_iter': 5000}

# nouveaux paramètres
params = {'hidden_layer_sizes': [36], 'max_iter': iteration, 'alpha': [38.2]}

gs_mlp = GridSearchCV(mlp, params, scoring = score, cv=splits)
gs_mlp.fit(X_train, y_train)
print('Multi-Layer Perceptron Regressor')
print('Params :', gs_mlp.best_params_)
print('Score', round(gs_mlp.best_score_*100,2))
# Out:
# Multi-Layer Perceptron Regressor
# Params : {'alpha': 38.2, 'hidden_layer_sizes': 36, 'max_iter': 5000}
# Score 20.46

# %%
from sklearn.inspection import permutation_importance
r = permutation_importance(gs_gbr, X_train, y_train, n_repeats=10, random_state=random)
for i in r.importances_mean.argsort()[::-1][:10]:
    if r.importances_mean[i] - 2 * r.importances_std[i] > 0:
        print(f"{X_train.columns[i]:<8} : "
            f"{r.importances_mean[i]:.3f}"
            f" +/- {r.importances_std[i]:.3f}")
# Out:
# Type_Non-Refrigerated Warehouse : 0.124 +/- 0.011
# mix_gas  : 0.073 +/- 0.007
# New_PropertyGFATotal : 0.071 +/- 0.007
# Type_Other : 0.068 +/- 0.005
# mix_elec : 0.059 +/- 0.006
# Type_Self-Storage Facility : 0.052 +/- 0.005
# Type_Distribution Center : 0.044 +/- 0.003
# Type_Worship Facility : 0.041 +/- 0.004
# YearBuilt : 0.039 +/- 0.003
# Type_Unknown : 0.032 +/- 0.002

# %% [markdown]
# ## <a name="C4.2"> Données avec Energy Star Score
# ### <a name="C4.2.1"> Données réelles

# %%
# Reprenons notre jeu de données et retirons les individus dont l'Energy Star Score est à 0 (valeurs absentes)
mask = data_final['ENERGYSTARScore'] != 0
data_energy_star = data_final[mask]
data_energy_star.describe()
# Out:
#        CouncilDistrictCode  Latitude  Longitude  YearBuilt  NumberofFloors  \
# count             770.0000  770.0000   770.0000   770.0000        770.0000
# mean                4.0584   47.6147  -122.3328 1,960.9584          2.5974
# std                 2.1457    0.0525     0.0260    31.1000          1.6204
# min                 1.0000   47.4992  -122.4118 1,900.0000          0.0000
# 25%                 2.0000   47.5735  -122.3455 1,937.2500          1.0000
# 50%                 4.0000   47.6132  -122.3324 1,965.0000          2.0000
# 75%                 6.0000   47.6559  -122.3207 1,985.0000          3.0000
# max                 7.0000   47.7339  -122.2586 2,015.0000          8.0000
#
#        ENERGYSTARScore  Enc_ComplianceStatus  mix_elec  mix_gas  mix_steam  \
# count         770.0000              770.0000  770.0000 770.0000   770.0000
# mean           65.6909                0.0961    0.7202   0.2798     0.0000
# std            27.8729                0.2949    0.2700   0.2700     0.0000
# min             1.0000                0.0000    0.0045   0.0000     0.0000
# 25%            50.0000                0.0000    0.5055   0.0000     0.0000
# 50%            73.0000                0.0000    0.7675   0.2325     0.0000
# 75%            88.0000                0.0000    1.0000   0.4945     0.0000
# max           100.0000                1.0000    1.0000   0.9955     0.0000
#
#        New_PropertyGFATotal  New_SiteEUIWN(kBtu/sf)  \
# count              770.0000                770.0000
# mean            59,812.8701                 45.4887
# std             42,317.2822                 24.2285
# min             12,294.0000                  2.1160
# 25%             30,000.0000                 29.8806
# 50%             45,735.5000                 42.1424
# 75%             73,714.0000                 56.5485
# max            293,707.0000                155.4755
#
#        New_GHGEmissionsIntensity  Building_Campus  Building_NonResidential  \
# count                   770.0000         770.0000                 770.0000
# mean                      0.8922           0.0026                   0.9013
# std                       0.8003           0.0509                   0.2985
# min                       0.0100           0.0000                   0.0000
# 25%                       0.2800           0.0000                   1.0000
# 50%                       0.6350           0.0000                   1.0000
# 75%                       1.3075           0.0000                   1.0000
# max                       4.0200           1.0000                   1.0000
#
#        Building_Nonresidential COS  Building_Nonresidential WA  \
# count                     770.0000                    770.0000
# mean                        0.0091                      0.0000
# std                         0.0950                      0.0000
# 25%                       0.0000            0.0000            0.0000
# 50%                       0.0000            0.0000            0.0000
# 75%                       0.0000            0.0000            0.0000
# max                       0.0000            1.0000            1.0000
#
#        Neighbor_DELRIDGE  Neighbor_DOWNTOWN  Neighbor_EAST  \
# count           770.0000           770.0000       770.0000
# mean              0.0364             0.1416         0.0519
# std               0.1873             0.3488         0.2221
# min               0.0000             0.0000         0.0000
# 25%               0.0000             0.0000         0.0000
# 50%               0.0000             0.0000         0.0000
# 75%               0.0000             0.0000         0.0000
# max               1.0000             1.0000         1.0000
#
#        Neighbor_GREATER DUWAMISH  Neighbor_LAKE UNION  \
# count                   770.0000             770.0000
# mean                      0.2494               0.0974
# std                       0.4329               0.2967
# min                       0.0000               0.0000
# 25%                       0.0000               0.0000
# 50%                       0.0000               0.0000
# 75%                       0.0000               0.0000
# max                       1.0000               1.0000
#
#        Neighbor_MAGNOLIA / QUEEN ANNE  Neighbor_NORTH  Neighbor_NORTHEAST  \
# count                        770.0000        770.0000            770.0000
# mean                           0.0948          0.0403              0.0870
# std                            0.2931          0.1967              0.2820
# min                            0.0000          0.0000              0.0000
# 25%                            0.0000          0.0000              0.0000
# 50%                            0.0000          0.0000              0.0000
# 75%                            0.0000          0.0000              0.0000
# max                            1.0000          1.0000              1.0000
#
#        Neighbor_NORTHWEST  Neighbor_SOUTHEAST  Neighbor_SOUTHWEST
# count            770.0000            770.0000            770.0000
# mean               0.0649              0.0351              0.0273
# std                0.2466              0.1841              0.1630
# min                0.0000              0.0000              0.0000
# 25%                0.0000              0.0000              0.0000
# 50%                0.0000              0.0000              0.0000
# 75%                0.0000              0.0000              0.0000
# max                1.0000              1.0000              1.0000
#
# [8 rows x 111 columns]

# %%
# Tests des modèles de prédiction de la consommation d'énergie

# Les données
y = data_energy_star['New_SiteEUIWN(kBtu/sf)']
X = data_energy_star[features_analysis_2]

# Ne standardisons que les variables qui en ont besoin
X_std = X.copy()
for col in col_std_2:
    mean = X[col].mean()
    std = X[col].std()
    X_std[col] = (X[col]-mean) / std
X_std.shape
# Out:
# (770, 109)

# %%
# Algo d'entrainement des modèles
# Titre
print("Modèles de prédiction des émissions de la consommation d'énergie (avec prise en compte de l'Energy Star Score):")
print(70*'-')

# Début des traitements
start = datetime.datetime.now()

# Données
X_train = X_std
y_train = y

# Ridge
params = { 'alpha': alphas, 'tol' : tolerance }
gs_ridge = GridSearchCV(ridge, params, scoring = score, cv=splits)
gs_ridge.fit(X_train, y_train)
print('Ridge :', gs_ridge.best_params_)
init_sum = [('Ridge', round(gs_ridge.best_score_*100,2))]
summary = pd.DataFrame(init_sum, columns = ['Model', 'R2'])

# Lasso
params = { 'alpha': alphas, 'tol' : tolerance , 'max_iter' : iter_calc }
gs_lasso = GridSearchCV(lasso, params, scoring = score, cv=splits)
gs_lasso.fit(X_train, y_train)
print('Lasso :', gs_lasso.best_params_)
summary.loc[1] = ['Lasso', round(gs_lasso.best_score_*100,2)]

# Elastic Net
params = { 'alpha': alphas, 'l1_ratio' : l1, 'tol' : tolerance,  'max_iter' : iter_calc }
gs_net = GridSearchCV(net, params, scoring = score, cv=splits)
gs_net.fit(X_train, y_train)
print('Elastic Net :', gs_net.best_params_)
summary.loc[2] = ['Elastic Net', round(gs_net.best_score_*100,2)]

# Kernel Ridge Regression
params = { 'alpha': alphas, 'gamma' : gammas, 'kernel' : kernel }
gs_krr = GridSearchCV(krr, params, scoring = score, cv=splits)
gs_krr.fit(X_train, y_train)
print('Kernel Ridge Regression :', gs_krr.best_params_)
summary.loc[3] = ['Kernel Ridge Regression', round(gs_krr.best_score_*100,2)]


# Random Forest Regressor
params = {'n_estimators': estimators}
gs_rfr = GridSearchCV(rfr, params, scoring = score, cv=splits)
gs_rfr.fit(X_train, y_train)
print('Random Forest Regressor :', gs_rfr.best_params_)
summary.loc[4] = ['Random Forest Regressor', round(gs_rfr.best_score_*100,2)]

# Gradient Boosting Regressor
params = {'n_estimators': estimators, 'learning_rate': learning_rate}
gs_gbr = GridSearchCV(gbr, params, scoring = score, cv=splits)
gs_gbr.fit(X_train, y_train)
print('Gradient Boosting Regressor :', gs_gbr.best_params_)
summary.loc[5] = ['Gradient Boosting Regressor', round(gs_gbr.best_score_*100,2)]

# Multi-Layer Perceptron Regressor
params = {'hidden_layer_sizes': layers, 'max_iter': iteration, 'alpha': alphas}
gs_mlp = GridSearchCV(mlp, params, scoring = score, cv=splits)
gs_mlp.fit(X_train, y_train)
print('Multi-Layer Perceptron Regressor :', gs_mlp.best_params_)
summary.loc[6] = ['Multi-Layer Perceptron Regressor', round(gs_mlp.best_score_*100,2)]

# Support Vector Regression
params = { 'C': Cs, 'tol' : tolerance, 'kernel' : kernel }
gs_svr = GridSearchCV(svr, params, scoring = score, cv=splits)
gs_svr.fit(X_train, y_train)
print('Support Vector Regression :', gs_svr.best_params_)
summary.loc[7] = ['Support Vector Regression', round(gs_svr.best_score_*100,2)]

# Fin des traitements
end = datetime.datetime.now()
print(70*'-')
print ("Start date and time : ", start.strftime("%Y-%m-%d %H:%M:%S"))
print ("End date and time : ", end.strftime("%Y-%m-%d %H:%M:%S"))

# Trions et affichons les résultats
summary = summary.sort_values(by = 'R2',ascending = False)
summary
# Out:
# Modèles de prédiction des émissions de la consommation d'énergie (avec prise en compte de l'Energy Star Score):
# ----------------------------------------------------------------------
# Ridge : {'alpha': 0.2782559402207126, 'tol': 0.01}
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 57140.6830838281, tolerance: 4232.341794046594
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 58121.25916383365, tolerance: 4087.24147625035
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 56863.128365929915, tolerance: 4127.419253798638
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 54791.636120181836, tolerance: 4053.3207308132596
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 58035.665471564746, tolerance: 4136.550785086932
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 57391.12528051894, tolerance: 4067.708976444962
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 54764.08305738737, tolerance: 4095.7534122661664
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 9719.52333492448, tolerance: 3965.065857572547
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 56483.47110545889, tolerance: 4061.288317853826
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 50399.581094165325, tolerance: 3793.313628646607
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 10979.721337242605, tolerance: 4232.341794046594
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 7770.4670268828195, tolerance: 4087.24147625035
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 10786.62632292528, tolerance: 4127.419253798638
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 11420.492968205086, tolerance: 4053.3207308132596
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 12010.31752844814, tolerance: 4136.550785086932
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap:
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (5000) reached and the optimization hasn't converged yet.
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (5000) reached and the optimization hasn't converged yet.
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (5000) reached and the optimization hasn't converged yet.
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (5000) reached and the optimization hasn't converged yet.
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (5000) reached and the optimization hasn't converged yet.
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (5000) reached and the optimization hasn't converged yet.
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (5000) reached and the optimization hasn't converged yet.
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (5000) reached and the optimization hasn't converged yet.
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (5000) reached and the optimization hasn't converged yet.
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (5000) reached and the optimization hasn't converged yet.
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (5000) reached and the optimization hasn't converged yet.
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (5000) reached and the optimization hasn't converged yet.
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (5000) reached and the optimization hasn't converged yet.
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (5000) reached and the optimization hasn't converged yet.
# Multi-Layer Perceptron Regressor : {'alpha': 46.41588833612782, 'hidden_layer_sizes': 60, 'max_iter': 5000}
# Support Vector Regression : {'C': 46.41588833612782, 'kernel': 'rbf', 'tol': 0.01}
# ----------------------------------------------------------------------
# Start date and time :  2022-09-01 00:05:41
# End date and time :  2022-09-01 00:50:39
#                               Model      R2
# 3           Kernel Ridge Regression 61.0300
# 6  Multi-Layer Perceptron Regressor 61.0300
# 2                       Elastic Net 60.4000
# 1                             Lasso 60.3900
# 0                             Ridge 60.3000
# 5       Gradient Boosting Regressor 60.1800
# 7         Support Vector Regression 55.0700
# 4           Random Forest Regressor 54.1500

# %%
# Tentons d'optimiser les hyperparamètres des 2 meilleurs modèles

# Kernel Ridge Regression
# Meilleur paramètre en première analyse : 
# {'alpha': 0.0016681005372000592, 'gamma': 0.0016681005372000592, 'kernel': 'rbf'}

# nouveaux paramètres
params = { 'alpha': [0.002], 'gamma' : [0.0013], 'kernel' : kernel }

gs_krr = GridSearchCV(krr, params, scoring = score, cv=splits)
gs_krr.fit(X_train, y_train)
print('Kernel Ridge Regression')
print('Params :', gs_krr.best_params_)
print('Score :', round(gs_krr.best_score_*100,2))
# Out:
# Kernel Ridge Regression
# Params : {'alpha': 0.002, 'gamma': 0.0013, 'kernel': 'rbf'}
# Score : 61.14

# %%
# Multi-Layer Perceptron Regressor
# Meilleur paramètre en première analyse : 
# {'alpha': 46.41588833612782, 'hidden_layer_sizes': 60, 'max_iter': 5000}

# nouveaux paramètres
params = {'hidden_layer_sizes': [58], 'max_iter': iteration, 'alpha': [45]}

gs_mlp = GridSearchCV(mlp, params, scoring = score, cv=splits)
gs_mlp.fit(X_train, y_train)
print('Multi-Layer Perceptron Regressor')
print('Params :', gs_mlp.best_params_)
print('Score :', round(gs_mlp.best_score_*100,2))
# Out:
# Multi-Layer Perceptron Regressor
# Params : {'alpha': 45, 'hidden_layer_sizes': 58, 'max_iter': 5000}
# Score : 61.73

# %%
from sklearn.inspection import permutation_importance
r = permutation_importance(gs_mlp, X_train, y_train, n_repeats=10, random_state=random)
for i in r.importances_mean.argsort()[::-1][:10]:
    if r.importances_mean[i] - 2 * r.importances_std[i] > 0:
        print(f"{X_train.columns[i]:<8} : "
            f"{r.importances_mean[i]:.3f}"
            f" +/- {r.importances_std[i]:.3f}")
# Out:
# ENERGYSTARScore : 0.731 +/- 0.030
# mix_gas  : 0.225 +/- 0.012
# Type_Non-Refrigerated Warehouse : 0.071 +/- 0.006
# Type_Office : 0.067 +/- 0.006
# Primary_Warehouse : 0.060 +/- 0.006
# Type_Retail Store : 0.050 +/- 0.008
# YearBuilt : 0.048 +/- 0.005
# New_PropertyGFATotal : 0.036 +/- 0.004
# Type_Worship Facility : 0.034 +/- 0.004
# Primary_Distribution Center : 0.029 +/- 0.003

# %% [markdown]
# ### <a name="C4.2.2"> Données réelles + données prédites

# %%
# Testons la méthode des knn pour l'Energy Star
mask = data_final['ENERGYSTARScore']==0
data_knn = data_final[~mask]
print(data_knn.shape)

X = data_knn.copy()
X.drop('ENERGYSTARScore', axis=1)
y = data_knn['ENERGYSTARScore'].copy()

# Ne standardisons que les variables qui en ont besoin
X_2 = X.copy()
for col in col_std_3:
    mean = X[col].mean()
    std = X[col].std()
    X_2[col] = (X[col]-mean) / std
X_std = X_2

splits = 10

# KNN
knn = neighbors.KNeighborsClassifier()
params = {'n_neighbors' : [5, 7, 11, 15]}
gs_knn = GridSearchCV(knn, params, scoring = score, cv=splits)
gs_knn.fit(X_std, y)
print('Knn best params :', gs_knn.best_params_)
print('Knn best score :', round(gs_knn.best_score_*100,2))

data_knn.boxplot(column='ENERGYSTARScore', vert=False, showfliers= True, showmeans=True)
plt.show()
# Out:
# (770, 111)
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning:
#
# The least populated class in y has only 1 members, which is less than n_splits=10.
# Knn best params : {'n_neighbors': 7}
# Knn best score : 99.84

# %%
# Appliquons les prédictions de notre modèle aux valeurs à 0 dans notre jeu de données :
mask = data_final['ENERGYSTARScore'] == 0
data_final.loc[mask, 'ENERGYSTARScore'] = gs_knn.predict(data_final.loc[mask, X_std.columns])

# %%
data_final.boxplot(column='ENERGYSTARScore', vert=False, showfliers= True, showmeans=True)
plt.show()

# %%
# Tests des modèles de prédiction de la consommation d'énergie

# Les données
y = data_final['New_SiteEUIWN(kBtu/sf)']
X = data_final[features_analysis_2]

# Ne standardisons que les variables qui en ont besoin
X_std = X.copy()
for col in col_std_2:
    mean = X[col].mean()
    std = X[col].std()
    X_std[col] = (X[col]-mean) / std
X_std.shape
# Out:
# (1153, 109)

# %%
# Algo d'entrainement des modèles
# Titre
print("Modèles de prédiction des émissions de la consommation d'énergie (avec Energy Star Score réel et prédit):")
print(70*'-')

# Début des traitements
start = datetime.datetime.now()

# Données
X_train = X_std
y_train = y

# Ridge
params = { 'alpha': alphas, 'tol' : tolerance }
gs_ridge = GridSearchCV(ridge, params, scoring = score, cv=splits)
gs_ridge.fit(X_train, y_train)
print('Ridge :', gs_ridge.best_params_)
init_sum = [('Ridge', round(gs_ridge.best_score_*100,2))]
summary = pd.DataFrame(init_sum, columns = ['Model', 'R2'])

# Lasso
params = { 'alpha': alphas, 'tol' : tolerance , 'max_iter' : iter_calc }
gs_lasso = GridSearchCV(lasso, params, scoring = score, cv=splits)
gs_lasso.fit(X_train, y_train)
print('Lasso :', gs_lasso.best_params_)
summary.loc[1] = ['Lasso', round(gs_lasso.best_score_*100,2)]

# Elastic Net
params = { 'alpha': alphas, 'l1_ratio' : l1, 'tol' : tolerance,  'max_iter' : iter_calc }
gs_net = GridSearchCV(net, params, scoring = score, cv=splits)
gs_net.fit(X_train, y_train)
print('Elastic Net :', gs_net.best_params_)
summary.loc[2] = ['Elastic Net', round(gs_net.best_score_*100,2)]

# Kernel Ridge Regression
params = { 'alpha': alphas, 'gamma' : gammas, 'kernel' : kernel }
gs_krr = GridSearchCV(krr, params, scoring = score, cv=splits)
gs_krr.fit(X_train, y_train)
print('Kernel Ridge Regression :', gs_krr.best_params_)
summary.loc[3] = ['Kernel Ridge Regression', round(gs_krr.best_score_*100,2)]


# Random Forest Regressor
params = {'n_estimators': estimators}
gs_rfr = GridSearchCV(rfr, params, scoring = score, cv=splits)
gs_rfr.fit(X_train, y_train)
print('Random Forest Regressor :', gs_rfr.best_params_)
summary.loc[4] = ['Random Forest Regressor', round(gs_rfr.best_score_*100,2)]

# Gradient Boosting Regressor
params = {'n_estimators': estimators, 'learning_rate': learning_rate}
gs_gbr = GridSearchCV(gbr, params, scoring = score, cv=splits)
gs_gbr.fit(X_train, y_train)
print('Gradient Boosting Regressor :', gs_gbr.best_params_)
summary.loc[5] = ['Gradient Boosting Regressor', round(gs_gbr.best_score_*100,2)]

# Multi-Layer Perceptron Regressor
params = {'hidden_layer_sizes': layers, 'max_iter': iteration, 'alpha': alphas}
gs_mlp = GridSearchCV(mlp, params, scoring = score, cv=splits)
gs_mlp.fit(X_train, y_train)
print('Multi-Layer Perceptron Regressor :', gs_mlp.best_params_)
summary.loc[6] = ['Multi-Layer Perceptron Regressor', round(gs_mlp.best_score_*100,2)]

# Support Vector Regression
params = { 'C': Cs, 'tol' : tolerance, 'kernel' : kernel }
gs_svr = GridSearchCV(svr, params, scoring = score, cv=splits)
gs_svr.fit(X_train, y_train)
print('Support Vector Regression :', gs_svr.best_params_)
summary.loc[7] = ['Support Vector Regression', round(gs_svr.best_score_*100,2)]

# Fin des traitements
end = datetime.datetime.now()
print(70*'-')
print ("Start date and time : ", start.strftime("%Y-%m-%d %H:%M:%S"))
print ("End date and time : ", end.strftime("%Y-%m-%d %H:%M:%S"))

# Trions et affichons les résultats
summary = summary.sort_values(by = 'R2',ascending = False)
summary
# Out:
# Modèles de prédiction des émissions de la consommation d'énergie (avec Energy Star Score réel et prédit):
# ----------------------------------------------------------------------
# Ridge : {'alpha': 3.593813663804626, 'tol': 0.01}
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 43953.877035246725, tolerance: 7783.108897253274
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 46794.71803474362, tolerance: 7864.882050515132
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 46163.59138027771, tolerance: 7812.607293311015
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 31777.524737293395, tolerance: 7646.246179842135
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 11774.967128323507, tolerance: 7573.046094956035
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 46214.87898547354, tolerance: 7712.53196386153
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 42129.87285677684, tolerance: 7614.324080667566
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 41652.06454439429, tolerance: 7260.238849475109
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 44610.5706852868, tolerance: 7818.901561952541
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22607.91372019291, tolerance: 7385.643195332291
# Lasso : {'alpha': 0.021544346900318846, 'max_iter': 20000, 'tol': 0.01}
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24889.856360034755, tolerance: 7783.108897253274
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 31695.965455773432, tolerance: 7864.882050515132
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 13977.570989921398, tolerance: 7812.607293311015
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 30668.51137551907, tolerance: 7646.246179842135
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 16556.758032238227, tolerance: 7573.046094956035
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 39288.06374563067, tolerance: 7712.53196386153
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 18162.22582963921, tolerance: 7614.324080667566
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 13701.6868784994, tolerance: 7260.238849475109
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 20150.125044208893, tolerance: 7818.901561952541
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 44020.56376799423, tolerance: 7385.643195332291
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 28749.639799235825, tolerance: 7783.108897253274
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 34863.89154667279, tolerance: 7864.882050515132
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23760.750997077208, tolerance: 7812.607293311015
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 48826.56841283967, tolerance: 7646.246179842135
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 29693.879125012172, tolerance: 7573.046094956035
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 63351.14678186475, tolerance: 7712.53196386153
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 34804.70104361125, tolerance: 7614.324080667566
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 27686.126029455336, tolerance: 7260.238849475109
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 29893.092960042384, tolerance: 7818.901561952541
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 63687.18809169647, tolerance: 7385.643195332291
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 49959.39954460834, tolerance: 7864.882050515132
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 40151.742563418666, tolerance: 7812.607293311015
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 56596.012526874634, tolerance: 7646.246179842135
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 38327.45469845459, tolerance: 7573.046094956035
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 79717.56696217199, tolerance: 7712.53196386153
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 50835.758480541204, tolerance: 7614.324080667566
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 43043.08441250233, tolerance: 7260.238849475109
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 48442.76663355244, tolerance: 7818.901561952541
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 70246.41825137075, tolerance: 7385.643195332291
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 43953.877034893405, tolerance: 7783.108897253274
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 46794.71803459636, tolerance: 7864.882050515132
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 46163.591378507175, tolerance: 7812.607293311015
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 31777.524736545514, tolerance: 7646.246179842135
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 11774.96712876868, tolerance: 7573.046094956035
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 46214.87898536629, tolerance: 7712.53196386153
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 42129.87285737108, tolerance: 7614.324080667566
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 41652.064544000896, tolerance: 7260.238849475109
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 44610.570685445244, tolerance: 7818.901561952541
#
# C:\Users\bruno\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22607.913722193363, tolerance: 7385.643195332291
# Elastic Net : {'alpha': 0.021544346900318846, 'l1_ratio': 0.7999999999999999, 'max_iter': 20000, 'tol': 0.01}
# Kernel Ridge Regression : {'alpha': 0.2782559402207126, 'gamma': 0.021544346900318846, 'kernel': 'rbf'}
# Random Forest Regressor : {'n_estimators': 450}
# Gradient Boosting Regressor : {'learning_rate': 0.02, 'n_estimators': 550}
# Multi-Layer Perceptron Regressor : {'alpha': 46.41588833612782, 'hidden_layer_sizes': 65, 'max_iter': 5000}
# Support Vector Regression : {'C': 46.41588833612782, 'kernel': 'rbf', 'tol': 0.01}
# ----------------------------------------------------------------------
# Start date and time :  2022-09-01 00:51:34
# End date and time :  2022-09-01 01:37:08
#                               Model      R2
# 5       Gradient Boosting Regressor 37.1700
# 6  Multi-Layer Perceptron Regressor 35.7000
# 4           Random Forest Regressor 35.3900
# 3           Kernel Ridge Regression 35.1900
# 2                       Elastic Net 34.2500
# 0                             Ridge 33.7000
# 1                             Lasso 33.0100
# 7         Support Vector Regression 32.3000

# %%
# Tentons d'optimiser les hyperparamètres des 2 meilleurs modèles

# Gradient Boosting Regressor
# Meilleur paramètre en première analyse : 
# {'learning_rate': 0.02, 'n_estimators': 550}

# nouveaux paramètres
params = {'n_estimators': [575], 'learning_rate': [0.02]}

gs_gbr = GridSearchCV(gbr, params, scoring = score, cv=splits)
gs_gbr.fit(X_train, y_train)
print('Gradient Boosting Regressor')
print('Params :', gs_gbr.best_params_)
print('Score :', round(gs_gbr.best_score_*100,2))
# Out:
# Gradient Boosting Regressor
# Params : {'learning_rate': 0.02, 'n_estimators': 575}
# Score : 37.17

# %%
# Multi-Layer Perceptron Regressor
# Meilleur paramètre en première analyse : 
# {'alpha': 46.41588833612782, 'hidden_layer_sizes': 65, 'max_iter': 5000}

# nouveaux paramètres
params = {'hidden_layer_sizes': [70], 'max_iter': iteration, 'alpha': [46.81]}

gs_mlp = GridSearchCV(mlp, params, scoring = score, cv=splits)
gs_mlp.fit(X_train, y_train)
print('Multi-Layer Perceptron Regressor')
print('Params :', gs_mlp.best_params_)
print('Score :', round(gs_mlp.best_score_*100,2))
# Out:
# Multi-Layer Perceptron Regressor
# Params : {'alpha': 46.81, 'hidden_layer_sizes': 70, 'max_iter': 5000}
# Score : 36.22

# %%
from sklearn.inspection import permutation_importance
r = permutation_importance(gs_gbr, X_train, y_train, n_repeats=10, random_state=random)
for i in r.importances_mean.argsort()[::-1][:10]:
    if r.importances_mean[i] - 2 * r.importances_std[i] > 0:
        print(f"{X_train.columns[i]:<8} : "
            f"{r.importances_mean[i]:.3f}"
            f" +/- {r.importances_std[i]:.3f}")
# Out:
# ENERGYSTARScore : 0.364 +/- 0.019
# Type_Non-Refrigerated Warehouse : 0.156 +/- 0.011
# mix_gas  : 0.074 +/- 0.005
# Type_Other : 0.065 +/- 0.003
# mix_elec : 0.065 +/- 0.004
# Type_Distribution Center : 0.059 +/- 0.006
# Type_Self-Storage Facility : 0.049 +/- 0.006
# Type_Worship Facility : 0.045 +/- 0.004
# New_PropertyGFATotal : 0.033 +/- 0.004
# Type_Unknown : 0.029 +/- 0.002
